# %% [markdown]
# <a href="https://colab.research.google.com/github/25041031-cloud/Probabilidad-/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadística**
# ##**Unidad 1**
# ###**Practica 3.Tabla de frecuencias y regla de Sturges..
# ###Docente: *Dr.José Gabriel Rodríguez Rivas*
# ###Alumno: Diego Armando García Amparan

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio=random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [69, 47, 45, 36, 33, 36, 47, 30, 34, 68, 44, 65, 54, 23, 25, 58, 60, 21, 63, 66, 52, 35, 42, 64, 32, 31, 20, 53, 58, 67, 40, 61, 55, 63, 58, 29, 40, 43, 37, 29, 63, 38, 44, 48, 29, 41, 23, 64, 19, 45, 36, 30, 32, 66, 38, 27, 47, 35, 61, 42, 33, 58, 51, 27, 48, 60, 35, 48, 56, 21, 55, 35, 30, 49, 67, 69, 31, 47, 53, 19, 51, 24, 45, 55, 55, 29, 65, 66, 70, 48, 27, 64, 60, 45, 49, 45, 61, 45, 21, 49]

# %%
import pandas as pd
df=pd.DataFrame(edades,columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    69
# 1    47
# 2    45
# 3    36
# 4    33

# %%
tabla_frecuencias=df['Edad'].value_counts().reset_index(0)
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')

print("Tabla  de Distribuciión de frecuencias:")
tabla_frecuencias
# Out:
# Tabla  de Distribuciión de frecuencias:
#     Edad  Frecuencia
# 20    19           2
# 35    20           1
# 12    21           3
# 26    23           2
# 41    24           1
# 34    25           1
# 13    27           3
# 3     29           4
# 7     30           3
# 25    31           2
# 27    32           2
# 18    33           2
# 33    34           1
# 5     35           4
# 10    36           3
# 38    37           1
# 29    38           2
# 21    40           2
# 39    41           1
# 28    42           2
# 37    43           1
# 23    44           2
# 0     45           6
# 1     47           4
# 6     48           4
# 14    49           3
# 19    51           2
# 36    52           1
# 24    53           2
# 31    54           1
# 4     55           4
# 40    56           1
# 2     58           4
# 16    60           3
# 11    61           3
# 8     63           3
# 15    64           3
# 22    65           2
# 9     66           3
# 30    67           2
# 32    68           1
# 17    69           2
# 42    70           1

# %%
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 20    19           2           0.02
# 35    20           1           0.01
# 12    21           3           0.03
# 26    23           2           0.02
# 41    24           1           0.01
# 34    25           1           0.01
# 13    27           3           0.03
# 3     29           4           0.04
# 7     30           3           0.03
# 25    31           2           0.02
# 27    32           2           0.02
# 18    33           2           0.02
# 33    34           1           0.01
# 5     35           4           0.04
# 10    36           3           0.03
# 38    37           1           0.01
# 29    38           2           0.02
# 21    40           2           0.02
# 39    41           1           0.01
# 28    42           2           0.02
# 37    43           1           0.01
# 23    44           2           0.02
# 0     45           6           0.06
# 1     47           4           0.04
# 6     48           4           0.04
# 14    49           3           0.03
# 19    51           2           0.02
# 36    52           1           0.01
# 24    53           2           0.02
# 31    54           1           0.01
# 4     55           4           0.04
# 40    56           1           0.01
# 2     58           4           0.04
# 16    60           3           0.03
# 11    61           3           0.03
# 8     63           3           0.03
# 15    64           3           0.03
# 22    65           2           0.02
# 9     66           3           0.03
# 30    67           2           0.02
# 32    68           1           0.01
# 17    69           2           0.02
# 42    70           1           0.01

# %%
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 20    19           2           0.02              2.0
# 35    20           1           0.01              1.0
# 12    21           3           0.03              3.0
# 26    23           2           0.02              2.0
# 41    24           1           0.01              1.0
# 34    25           1           0.01              1.0
# 13    27           3           0.03              3.0
# 3     29           4           0.04              4.0
# 7     30           3           0.03              3.0
# 25    31           2           0.02              2.0
# 27    32           2           0.02              2.0
# 18    33           2           0.02              2.0
# 33    34           1           0.01              1.0
# 5     35           4           0.04              4.0
# 10    36           3           0.03              3.0
# 38    37           1           0.01              1.0
# 29    38           2           0.02              2.0
# 21    40           2           0.02              2.0
# 39    41           1           0.01              1.0
# 28    42           2           0.02              2.0
# 37    43           1           0.01              1.0
# 23    44           2           0.02              2.0
# 0     45           6           0.06              6.0
# 1     47           4           0.04              4.0
# 6     48           4           0.04              4.0
# 14    49           3           0.03              3.0
# 19    51           2           0.02              2.0
# 36    52           1           0.01              1.0
# 24    53           2           0.02              2.0
# 31    54           1           0.01              1.0
# 4     55           4           0.04              4.0
# 40    56           1           0.01              1.0
# 2     58           4           0.04              4.0
# 16    60           3           0.03              3.0
# 11    61           3           0.03              3.0
# 8     63           3           0.03              3.0
# 15    64           3           0.03              3.0
# 22    65           2           0.02              2.0
# 9     66           3           0.03              3.0
# 30    67           2           0.02              2.0
# 32    68           1           0.01              1.0
# 17    69           2           0.02              2.0
# 42    70           1           0.01              1.0

# %%
tabla_frecuencias['Frec Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 20    19           2           0.02              2.0               2
# 35    20           1           0.01              1.0               3
# 12    21           3           0.03              3.0               6
# 26    23           2           0.02              2.0               8
# 41    24           1           0.01              1.0               9
# 34    25           1           0.01              1.0              10
# 13    27           3           0.03              3.0              13
# 3     29           4           0.04              4.0              17
# 7     30           3           0.03              3.0              20
# 25    31           2           0.02              2.0              22
# 27    32           2           0.02              2.0              24
# 18    33           2           0.02              2.0              26
# 33    34           1           0.01              1.0              27
# 5     35           4           0.04              4.0              31
# 10    36           3           0.03              3.0              34
# 38    37           1           0.01              1.0              35
# 29    38           2           0.02              2.0              37
# 21    40           2           0.02              2.0              39
# 39    41           1           0.01              1.0              40
# 28    42           2           0.02              2.0              42
# 37    43           1           0.01              1.0              43
# 23    44           2           0.02              2.0              45
# 0     45           6           0.06              6.0              51
# 1     47           4           0.04              4.0              55
# 6     48           4           0.04              4.0              59
# 14    49           3           0.03              3.0              62
# 19    51           2           0.02              2.0              64
# 36    52           1           0.01              1.0              65
# 24    53           2           0.02              2.0              67
# 31    54           1           0.01              1.0              68
# 4     55           4           0.04              4.0              72
# 40    56           1           0.01              1.0              73
# 2     58           4           0.04              4.0              77
# 16    60           3           0.03              3.0              80
# 11    61           3           0.03              3.0              83
# 8     63           3           0.03              3.0              86
# 15    64           3           0.03              3.0              89
# 22    65           2           0.02              2.0              91
# 9     66           3           0.03              3.0              94
# 30    67           2           0.02              2.0              96
# 32    68           1           0.01              1.0              97
# 17    69           2           0.02              2.0              99
# 42    70           1           0.01              1.0             100

# %%
import math
print(edades)
# Out:
# [69, 47, 45, 36, 33, 36, 47, 30, 34, 68, 44, 65, 54, 23, 25, 58, 60, 21, 63, 66, 52, 35, 42, 64, 32, 31, 20, 53, 58, 67, 40, 61, 55, 63, 58, 29, 40, 43, 37, 29, 63, 38, 44, 48, 29, 41, 23, 64, 19, 45, 36, 30, 32, 66, 38, 27, 47, 35, 61, 42, 33, 58, 51, 27, 48, 60, 35, 48, 56, 21, 55, 35, 30, 49, 67, 69, 31, 47, 53, 19, 51, 24, 45, 55, 55, 29, 65, 66, 70, 48, 27, 64, 60, 45, 49, 45, 61, 45, 21, 49]

# %%
df=pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     69
# 1     47
# 2     45
# 3     36
# 4     33
# ..   ...
# 95    45
# 96    61
# 97    45
# 98    21
# 99    49
#
# [100 rows x 1 columns]

# %%
n=len(edades)
K=int(1+math.log2(n))
print("Valor de n= ",n," \nNúmero de intervalos =",K)
# Out:
# Valor de n=  100
# Número de intervalos = 7

# %%
tabla_frecuencia=pd.cut(df['Edad'],bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns=['Clase','Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.857, 48.143]    20
# 1    (62.714, 70.0]    17
# 2  (26.286, 33.571]    16
# 3  (48.143, 55.429]    13
# 4  (33.571, 40.857]    13
# 5  (55.429, 62.714]    11
# 6  (18.948, 26.286]    10

# %%
tabla_frecuencia=tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 6  (18.948, 26.286]    10
# 2  (26.286, 33.571]    16
# 4  (33.571, 40.857]    13
# 0  (40.857, 48.143]    20
# 3  (48.143, 55.429]    13
# 5  (55.429, 62.714]    11
# 1    (62.714, 70.0]    17

# %%
tabla_frecuencia['Frec Rel']=tabla_frecuencia['Frec']/n
tabla_frecuencia['Frec Porc']=tabla_frecuencia['Frec']/n*100
tabla_frecuencia['Frec Ac']=tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac']=tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac']=tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 6  (18.948, 26.286]    10      0.10       10.0       10         0.10
# 2  (26.286, 33.571]    16      0.16       16.0       26         0.26
# 4  (33.571, 40.857]    13      0.13       13.0       39         0.39
# 0  (40.857, 48.143]    20      0.20       20.0       59         0.59
# 3  (48.143, 55.429]    13      0.13       13.0       72         0.72
# 5  (55.429, 62.714]    11      0.11       11.0       83         0.83
# 1    (62.714, 70.0]    17      0.17       17.0      100         1.00
#
#    Frec Porc Ac
# 6          10.0
# 2          26.0
# 4          39.0
# 0          59.0
# 3          72.0
# 5          83.0
# 1         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha=0.5)
plt.title("Histograma de edades basadaeb la función de matplotlib con valore estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basadaeb la función de matplotlib con valore estandar')

# %%
plt.hist(df['Edad'],bins=K,alpha=0.5)
plt.title('Histograma de edades basado en la egla de Sturgles')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
